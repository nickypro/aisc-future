# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import random_split
from torch.utils.data import DataLoader, TensorDataset
import torch
import torch.nn.functional as F
from taker import Model
id = 1

# %%
# Load texts
id = 1
loaded_texts  = torch.load(f'generated_texts-{id}.pth')
prompts = [i[0] for i in loaded_texts]
completions = [i[1] for i in loaded_texts]

# %%
# Generate activations if there are none

m = Model("mistralai/Mistral-7B-v0.1", dtype="int4") 
m.to("cuda")
m.do_activations["mlp_pre_out"] = False
m.do_activations["attn_pre_out"] = False




activations = []




with torch.no_grad():
    
    for text in [i for i in prompts]:
        activation = m.get_text_activations(text=text)
        input = activation[0]
        atten_out = activation[1]
        ff_out = activation[2]
        out = activation[3]
        
        
        
        
        activations.append((atten_out[:, -5: -1, :], ff_out[:, -5: -1, :], out))


torch.save(activations, f"text_activations-{id}.pth")

# %%
# Load activations 

activations = torch.load(f"text_activations-{id}.pth")

# %%
# Inspect text


a = 0
for i in loaded_texts:
    print("TEXTS: ", a )
    print(i[0] + "//" +  i[1])
    
    a = a + 1
# Out:
# TEXTS:  0
# The Casa de la Cultura is located in the center of Fuengirola and is a building where of all kinds cultural activities are taken place.
# On the ground //ﬂoor of the building there is the tourist oﬃce, where information is given about the city and the Costa del Sol. On the ﬁrst ﬂoor there is a library, the city museum and the Casa de la Juventud. On the second ﬂoor there are a theater, a room for exhibitions, a chamber for meetings and another for conferences. It is a big building with a lot of activities that you can go to. In this building there are also 2 restaurants.
#
# Opening hours:
# Tuesday to Friday: 10:30 – 15:00
# Saturday: 10:30 – 14:00
# Closed on Sundays and Mondays.
#
# Address:
# Plaza de la Constitución, 1 (next to the police station)
#
# Telephone number: 952 473 584
#
# Website: www.culturayturismo.fuengirola.es
# TEXTS:  1
# Au revoir, Nexus 5! Google is no longer officially selling its 2013 champion
# The end of an era has come - Google has officially stopped selling the Ne//exus 5 through the Google Store. The Nexus 5, which was the best Android phone of 2013, was released in 2013 with an official price tag of $349 for the 16GB version and $399 for the 32GB model.
#
# Google has been selling the Nexus 5 for $299 for the 16GB model and $349 for the 32GB model. It's still available on the Google Store (but not through a link), though.
#
# It's not a huge surprise that Google has stopped selling the Nexus 5. The 2014 Nexus phones, the Nexus 6 and Nexus 9, were announced earlier this month. The Nexus 5 is the best-selling Google phone of all time and it has been the best-selling Android phone for the last year.
# TEXTS:  2
# Oxycodone Dosage
# An opioid pain medication, oxycodone is used to treat moderate to severe pain. Oxycodone is taken orally and is available in capsule,// tablet, and liquid forms. Oxycodone is also available as a narcotic pain reliever in combination with acetaminophen or aspirin. Oxycodone is also available in a controlled-release capsule that can be opened and the contents sprinkled on applesauce or pudding, or mixed in a small amount of applesauce or pudding.
#
# Oxycodone is a narcotic pain reliever, and it relieves pain by changing the way the brain responds to pain. Oxycodone comes in several forms, but all oxycodone products are controlled substances, which means that they can be misused.
#
# Oxycodone is commonly prescribed to treat:
#
# - Pain due to a variety of medical conditions, including osteoporosis, rheumatoid arthritis, and cancer
# - Severe pain following surgery
#
# Oxycodone should not be taken in combination with other narcotic pain relievers. Oxycodone should only be taken by the individual for whom it was prescribed.
#
# The oxycodone dosage prescribed by your doctor should be taken as prescribed. Oxycodone is available in several different forms, including:
#
# - OxyContin® – an extended-release tablet or capsule containing 5, 10, 15, 20,
# TEXTS:  3
# Cambridge clinched their first Varsity win since 2009 as they beat Oxford in a highly entertaining match at Twickenham.
# A late try from Rory Triniman // and a conversion from Will Beer secured a 26-19 win.
#
# Oxford’s Tom Smyth-Kirkham, right, is tackled by Cambridge University’s Tom Davies during their Varsity match at Twickenham
#
# Cambridge’s Tom Davies, right, tackles Oxford University’s Ben Cooper during their Varsity match at Twickenham
#
# Oxford’s Tom Smyth-Kirkham scores a try during their Varsity match against Cambridge University at Twickenham
#
# Cambridge’s Tom Davies is tackled by Oxford’s Tom Smyth-Kirkham during their Varsity match at Twickenham
#
# Oxford’s Tom Smyth-Kirkham, left, is tackled by Cambridge’s Will Beer during their Varsity match at Twickenham
#
# Oxford’s Tom Smyth-Kirkham, right, is tackled by Cambridge’s Tom Davies during their Varsity match at Twickenham
#
# Cambridge’s Will Beer, right, celebrates with team mates after scoring a try during their Varsity match against Oxford University at Twickenham
#
# Cambridge’s Will Beer, right, celebrates with team mates after scoring a try during their Varsity match against Oxford University at Twicken
# TEXTS:  4
# Viagra is one of various penis extension things available today. This thing survey article will talk about how the tantamount to can be normal Bioperi//obol, how it works for your penis and the way in which you can get it.
#
# Viagra is a prescription drug used to treat erectile dysfunction and pulmonary hypertension. It is usually taken as a pill, but can also be used in other ways.
#
# ## What is Viagra?
#
# Viagra is a drug that can be used to treat erectile dysfunction (ED). It works by increasing blood flow to the penis, which can help to improve erections. Viagra can be taken as a pill, but can also be injected into the penis.
#
# ## How does Viagra work?
#
# Viagra is a drug that can be used to treat erectile dysfunction in men. It works by increasing blood flow to the penis, which can help men to achieve and maintain an erection. Viagra is available in tablet form and can be taken as needed, usually about 30 minutes before sexual activity. It is important to note that Viagra does not work for everyone and it is not a cure for erectile dysfunction. However, it can be a helpful treatment option for many men.
#
# ## What are the benefits of Viagra?
#
# Viagra is a drug that can be used to treat erectile dysfunction. It works by increasing blood flow to the penis, which can help to achieve and maintain an erection. Viagra can also be used to treat
# TEXTS:  5
# Gamespot Ponders the Return of the Space Sim
# GameSpot has posted a new video on the state of the space sim industry after years of relative hibernatio//
#
# Gamespot Ponders the Return of the Space Sim
# GameSpot has posted a new video on the state of the space sim industry after years of relative hibernation. It's a great video, and a great piece of investigative journalism.
#
# To view the video, click here.
#
# To read the article, click here.
#
# To read our previous story on the same subject, click here.
# - Ignorance is bliss
# - So if we can play any game we want on a PC, then what is the point of the PC as a gaming platform?
#
# The only thing I can come up with is that, even though the PS4/Xbox One is more powerful in terms of raw horsepower, it is missing the ability to make use of the PC's superior processing power for other tasks. If I can run my games on a console, but can't do any other work on it, I'll be much happier on an all-in-one gaming/workstation PC.
# - @sleet:
#
# > So if we can play any game we want on a PC, then what is the point of the PC as a gaming platform?
#
# PC gaming is more than playing games. It's also about modding games, creating content, playing multi-player games with friends, chatting in voice chat or IRC, and so on.
#
# TEXTS:  6
# - What is bioluminescence?
# - How deep in the ocean do giant isopods live?
# - Do people eat giant isopods?
# Find out the answers to these questions and m//unch on some giant isopod facts in this article!
#
# ## Giant Isopods
#
# The giant isopod is a fascinating marine crustacean that lives in the deepest parts of the ocean. Although they are technically considered to be crabs (yes, they are in the same taxonomic group!), their appearance makes them look more like lobsters.
#
# These fascinating creatures are often found in the cold and deep waters of the North Pacific Ocean. They can grow up to 40 cm (16 in) in length and are the largest of all the isopods.
#
# Giant isopods are found in the deepest parts of the ocean where sunlight can’t reach. They are bioluminescent, meaning they create their own light. This is used for two purposes: to find food and to communicate with other isopods.
#
# There are several species of giant isopod, but the most common are the:
#
# - Armadillidium vulgare
# - Armadillidium granulatum
# - Armidillidium nasutum
#
# Read on to learn more about these fascinating creatures!
#
# ## What is bioluminescence?
#
# Bioluminescence is the production of light by a living organism. It is most commonly seen in marine creatures, but can also be found in some land animals
# TEXTS:  7
# Three dishes you have to try at… Mannion & Co
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose passio//…
#
# Three dishes you have to try at… The Bottle of Sauce
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose passion…
#
# Three dishes you have to try at… The Ritz
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose pas…
#
# Three dishes you have to try at… Eat of Eden
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose passi…
#
# Three dishes you have to try at… The Ninth Wave
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose pas…
#
# Three dishes you have to try at… The Vineyard
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose pas…
#
# Three dishes you have to try at… Giles Coren’s Ivy House
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose pas…
#
# Three dishes you have to try at… The Laughing Gravy
# I love my job. I get the opportunity to work with really talented chefs and food producers, whose pas…
#
# Three dishes you have to try at… The Gherkin
# I love my job. I
# TEXTS:  8
# We are continuously working toward tailoring our online and offline services to fit your needs. In an effort to make this site more informative, helpf//ule, and attractive, we've been making some changes to the way the content is organized. We hope you like it.
#
# There are plenty of options for moving around the site—we've added breadcrumbs and navigation to the top of every page. The breadcrumbs are located at the top of each page, and show you where you are in the site structure. The navigation is located at the top of each page, and allows you to jump to any page on the site.
#
# The site structure has also changed. We've grouped information together to make it easier to find. You can still search for what you need, but we hope the site structure helps you find what you need.
# TEXTS:  9
# Summary
# Short description
# Capital culture meets barefoot luxury
# Our Flexibility Promise
# With our Flexibility Promise, you can rest assured that, shoul// you need to change or cancel your holiday, you can do so right up to the balance due date.
#
# Exclusive offer: Enjoy a 20% discount on this holiday. T&Cs apply.
#
# Perched on a hilltop, this luxury villa with infinity pool boasts a sublime location.
#
# Spectacular views of the sea and the mountains are the icing on the cake of this beautiful, whitewashed house.
#
# With its barefoot luxury approach, this villa is the perfect place to reconnect with nature and enjoy the peace of the countryside.
#
# The villa is located in a valley surrounded by pine forests and hills, with the sea and the sky as a backdrop.
#
# The villa has a spacious garden and a 300-square-meter infinity pool, which is ideal for a leisurely swim or an afternoon of sunbathing.
#
# The villa is built on a hill, and has a unique, rustic style.
#
# The house is decorated in a minimalist style, in shades of white and gray, with touches of wood and exposed brick.
#
# The villa has 3 bedrooms with en-suite bathrooms, and a large, open-plan living area.
#
# The villa also has a beautiful outdoor dining area and a kitchen with a large island.
#
# The villa is ideal for
# TEXTS:  10
# Cogsworth, the majordomo of the Beast's castle, receives the pop art treatment by renowned artist Romero BRITTO. With vibrant warm colors and patterns//, Cogsworth is a perfect addition to your collection of Disney Villains.
#
# Edition Size: 350
#
# Release Date: March 18, 2022
#
# Dimensions: 8" x 8" x 1/2"
#
# ROMERO BRITTO is one of the most popular and iconic artists of our time. Romero’s work is exhibited in galleries and museums in over 150 countries and his work has been exhibited in some of the most prestigious museums in the world. Romero’s art is in the permanent collections of the world’s most renowned museums, including the Modern Art Museum of Paris, the Museum of Contemporary Art in Shanghai and the Museum of Modern Art in Rio de Janeiro. Romero’s art has been exhibited in some of the most prestigious museums in the world. Romero’s art has been exhibited in some of the most prestigious museums in the world. Romero’s art has been exhibited in some of the most prestigious museums in the world. Romero’s art has been exhibited in some of the most prestigious museums in the world. Romero’s art has been exhibited in some of the most prestigious museums in the world. Romero’s art has been exhibited in some of the most prestigious museums
# TEXTS:  11
# 60" Lambros Single Bath Vanity
# was $1,999.00 Special Price $1,599.00
# In stock
# Large and stately, the 60" Lambros Single Bath Vanity will completely tr//anform your bathroom. It's made from 100% solid wood, so it's durable and easy to maintain. Each piece is made to order and is available in natural or black stain.
# - Ships in 10-14 weeks
# - Made from 100% solid wood
# - Made in the USA
# Product Details
#
# The 60" Lambros Single Bath Vanity is a gorgeous addition to any bathroom. It's made from 100% solid wood and is durable enough to last for years to come. It comes with an optional under-mount sink, and it's available in natural or black stain.
#
# Lambros is a family-owned business that has been making furniture in the United States for over 30 years. All of their products are made in the USA, which means that buying their furniture helps support American workers.
#
# This item is made-to-order and ships in 10-14 weeks.
#
# Shipping and Delivery
#
# We offer free shipping on most orders. When you're checking out, you'll be shown the shipping options available. We ship internationally, please let us know if you have any questions.
#
# If you're in the Chicago area, we now offer local pickup at our showroom.
#
# For more information, visit our Shipping & Delivery page.
#
# Sizing &
# TEXTS:  12
# Thought Leader Life 206: Guest Jamie Mustard
# Gain strong digital visibility by discovering your iconic message. This episode features #ThoughtLeader a// Jamie Mustard, a brand strategist, writer, and speaker. He’s the author of “The Iconic Brand”. He helps iconic brands like Apple, Starbucks, and Amazon to gain strong digital visibility.
#
# Here are a few of the highlights from our conversation:
# Jamie’s thoughts on the iconic message and what it means.
#
# - The iconic message is a core message that’s been distilled down to its most concentrated form.
# - It’s a differentiating message.
# - It’s a message that can be understood at a glance.
# - It’s a message that can be used over and over again.
# - It’s a message that can be used internally and externally.
# - It’s a message that can be used by anybody in the company.
#
# Jamie’s thoughts on how the iconic message can be used in your business.
#
# - It can be used for your website.
# - It can be used for your social media presence.
# - It can be used for your sales team.
# - It can be used for your advertising.
# - It can be used for your company culture.
# - It can be used for your leadership.
#
# To learn more about Thought Leadership and how it can help you be successful, subscribe to the channel:  http://youtube.com/user/thoughtleaderlife
# TEXTS:  13
# Top 10 gold mining companies of 2019 Find out which companies produced the most gold in 2019 Read on to learn about each.
# May 29 2009 · The Five Geoth//ite Mining Companies That Make Gold In 2020 Gold is the most popular precious metal in the world. It is a yellow colored metal that is soft and ductile. Gold is used in jewelry and also in many other products as well.
# Jul 24 2011 · The Gold Mining industry in Australia is worth around 165 billion Australian dollars in 2011. The Gold Mining industry includes the mining of gold in Australia and the export of gold from Australia. The Gold Mining industry also includes the production of gold bullion in Australia.
# Aug 02 2020 · A gold mining company is not the same as a bullion company which is why the price of gold and the price of gold mining shares can move differently. Gold mining companies take the raw material produced from mines and refine it into investment grade bullion.
# Mar 28 2018 · The Top 10 Gold Producing Countries 5 Ghana 956 000 ounces 4 Uzbekistan 965 000 ounces 3 Russia 10 400 000 ounces 2 South Africa 116 000 ounces 1 China 120 000 ounces 100 000 ounces 18
# TEXTS:  14
# -
# Pdf Beyond Listening Learning The Secret Language Of Focus Groups 2001by Annabel 3.5
# - Recommended land patterns
# - Recommended reflow soldering pro//totypes
# - Recommended soldering to through-hole pins
# - Recommended through-hole soldering
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Recommended through-hole soldering to a board
# - Re
# TEXTS:  15
# News
# Blu-ray Review: Tobe Hooper’s THE MANGLER
# January 12, 2019 Patrick Bromley - Dailydead.com
# One Hooper film still in need of a widespread critical// reappraisal is 1995’s THE MANGLER. While Hooper’s films tend to be either beloved or reviled, there’s a whole lot of middle ground that many of his movies are falling through. THE MANGLER, the story of a haunted dryer (yes, you read that correctly) that kills and eats the people who get stuck in it, is one such film.
#
# THE MANGLER was written by Richard Fire and Steven-Charles J. Sinclair from a story by Fire and Tobe Hooper. Unlike many of the lesser-known Hooper films, this one was actually a studio production. New Line was the studio, and they were the ones who put the money up to give THE MANGLER a huge budget of $11 million.
#
# THE MANGLER is a strange movie, and one that’s a little difficult to describe. It’s essentially a horror film, but it’s not like every other horror film that’s ever been made. The idea of a haunted dryer was so strange and outlandish in the mid-90s that it was almost impossible to market.
#
# But, hey, it’s Tobe Hooper! A lot of people tend to forget that THE MANGLER was a huge hit, especially when you consider how it was marketed. It was a box office
# TEXTS:  16
# We also have that nine out of ten interested books need involved by an Recommended Internet Page with the download, Helicobacter data and backwards by// the download that it is. This can be found in the PDF as a system. In the PDF, the web is the download that is in the web and is described in the download as the download and the other. In an PDF, the other that is in the web is the web that is the download and the other has a web in the system. The other that is in the web is the download that is in the web and is in the other of the web.
# TEXTS:  17
# The Atrocious Senate Kills Bill to Cap Property Tax
# I fully realize that describing the North Dakota Senate as "atrocious" is a harsh indictment. Neve// the less, that's what it is and what it has been for a long time.
#
# The state Senate, which has the power to confirm or reject legislation that has passed the House, has a history of killing bills that have overwhelming backing in the North Dakota House.
#
# And, last week, the Senate did it again.
#
# The Senate killed a bill that would cap property tax increases in the state.
#
# The state Senate has a history of killing bills that have overwhelming backing in the North Dakota House.
#
# The bill, HB 1062, passed the House in January by a vote of 96-3.
#
# But the Senate killed it last week by a vote of 20-30.
#
# But the Senate killed it last week by a vote of 20-30.
#
# The bill, HB 1062, passed the House in January by a vote of 96-3.
#
# The bill would have capped property tax increases in the state at 3 percent.
#
# The bill would have capped property tax increases in the state at 3 percent.
#
# The Senate's vote to kill the legislation was a shameful act.
# TEXTS:  18
# Me and Marvin Gardens
# Scholastic Inc | ISBN 9780545870764 Paperback
# 272 Pages | 5.24" x 7.58" | Ages 8 to 12
# Scholastic Inc | ISBN 9780545870740 Hardc//ove
# 272 Pages | 5.24" x 7.58" | Ages 8 to 12 | Lexile ® 710L
#
# In this middle grade novel, perfect for fans of The Dollhouse, Marvin Gardens is a unique and touching story about friendship, family, and the healing power of art.
#
# Rocky Ferguson feels like a total misfit. He’s got a new stepmom who owns a gallery of famous artists, and he’s got to move to a new city. And he’s got to attend a new school. And he’s got to make new friends. But on top of that, he’s got to figure out what to do with his father, who’s been acting very strangely since his mother died.
#
# But when Rocky meets Marvin, a boy who lives in the old house next to Rocky’s, a house that’s been abandoned for years, the two become best friends. Marvin is a little strange, too—he never talks, he rarely leaves his room, and he always carries around a sketchbook. But when Rocky realizes that Marvin’s talent is something special, he has to come to terms with the fact that Marvin may not be able to realize his own potential in the world.
#
# With a heartfelt storyline, a winning
# TEXTS:  19
# Sauté onion, green pepper, and garlic in olive oil in a large skillet; add tomatoes, tomato sauce, lime juice, Worcestershire sauce, salt, pepper, ore//gano, and bay leaf. Simmer 10 minutes. Bring 2 quarts of water to a boil. Add pork, reduce heat, and simmer 15 minutes. Drain pork and add to the tomato mixture; heat.
#
# Remove fat from ground pork with a spoon; add to the tomato mixture and stir. Cook until the meat loses its pink color. Add cooked rice, a little at a time, and mix. Simmer on low heat for 5 minutes.
#
# Sprinkle with cheese and serve.
#
# Servings: 8
# TEXTS:  20
# Inkspire: Unboxing & First Use
# Zortrax Inkspire is a resin 3D printer working in the UV LCD technology. This technology involves projecting an image o//...
#
# - Inkspire: Unboxing & First Use
#
# Zortrax Inkspire is a resin 3D printer working in the UV LCD technology. This technology involves projecting an image onto a vat of liquid resin. A UV light source then cures the exposed material, building-up the layers of the part.
#
# Inkspire is a new printer from the Polish manufacturer Zortrax. It’s their first printer in the resin category. Zortrax has been a manufacturer of FFF 3D printers for a while, so a leap into the resin category is a bold move. One that speaks for their confidence.
#
# Zortrax Inkspire is more precisely a multicolor resin printer. The machine is able to use two resin tanks simultaneously, mixing the contents of the two tanks together. This allows for multicolor prints.
#
# Zortrax Inkspire is the only resin printer that works in the UV LCD technology. It’s also the only resin printer that uses an open vat technology. These two features make this printer unique in the resin category.
#
# The printer comes in a rather big and heavy box. It weighs more than 20 kilograms, so it will surely give you a workout when you take it out of the packaging.
#
# The printer is
# TEXTS:  21
# Description
# Link up in PARLANE. Our dual texture, bar cufflinks are sure to draw some attention so make you give that shirt a good iron. Wouldn’t want// to be caught out in a creased shirt when you’re wearing these.
#
# The Designer
#
# Parlane
#
# Parlane is a brand for the sophisticated gentleman. Our men’s accessories are designed and manufactured in the UK by highly skilled craftsmen and are carefully selected by our experienced, fashion-savvy team. The brand focuses on quality and functionality, and we only use the finest materials so you can be confident your cufflinks, tie pins, tie clips, tie bars, stud sets, tie tacks, wallet chains, and key rings will last for decades.
#
# All our products are made using the finest materials. The cufflinks are made from gold-plated gun metal and stainless steel. The tie pins, tie clips, tie bars, tie tacks and key rings are made from stainless steel, and the studs and tie tacks are made from gold-plated gun metal.
# TEXTS:  22
# Sister Annabel Laity
# Sister Annabel Laity (Chan Duc, True Virtue) was born in England, and studied Classics and Sanskrit before going to India to stud// the Buddhist tradition. She lived for long periods in Buddhist monasteries in India, Sri Lanka and Thailand. She lived with the Buddhists for ten years, and became a Buddhist nun. In 1977, she met Chakma Master Huang-Po, who was then living in London. She stayed with him for some years, and was ordained as a nun in the Chakma lineage in 1982.
#
# She has translated a number of Buddhist texts from the Pali, Sanskrit and Chinese, and has also written a number of books. Her publications include :
#
# She currently lives in France and teaches Chan, and is a member of the Eurasian Scientific and Cultural Association.
#
# For more information go to www.annabel-laity.com.
# TEXTS:  23
# Trinity English Lutheran congregation was founded on November 18, 1918. Requesting their release from their German-speaking mother congregation, St. P//ETER’S, Trinity members were granted a charter and were formally organized as a church on February 27, 1919.
#
# The founding of Trinity was a direct result of the formation of the German-speaking congregation of St. Peter’s (now First English) in 1859. St. Peter’s had become overcrowded, and the need for a second German-speaking church was recognized.
#
# The first pastor of Trinity, Rev. A. H. P. Lohman, was installed in 1919. The first church (a frame building) was erected in 1921. The cornerstone of the present church was laid in 1929.
#
# The present-day facility was remodeled in 1974.
#
# Trinity English Lutheran Church
# 1730 Washington Street
# Albany, OR 97321
#
# Phone 541-926-3324
#
# Office Hours
# Tuesday-Friday
# 9 am-3 pm
#
# Email: office@trinity-albany.org
# Website: trinity-albany.org
# TEXTS:  24
# Lucan Harriers Fit4Life is aimed at men and women who would like to get fit in a social and fun environment. You can be a complete beginner or someone// working on your fitness or taking up running once again.
#
# We meet on Tuesday nights at 8.30pm in the car park of the Lucan Sarsfields GAA Club, Lucan, Co. Dublin.
#
# The session will last for about an hour, and will include a mixture of walking, jogging and running. Each week will be different, so you will not get bored.
#
# We hope that by the end of 2015 you will have achieved your fitness goals, and will be able to train with the club and take part in our races.
#
# It is very important that you are fit and healthy to take part in this new initiative and we would expect you to have a basic level of fitness.
#
# If you are interested, fill in the Fit4Life Registration Form and email to our Fit4Life officer, Liam McCaffrey, or print and hand in to the club.
#
# ## Contact
#
# For more information, contact Liam McCaffrey.
# TEXTS:  25
# BOOK Sap Nation 3 0 Manifest Destiny English Edition.PDF. You can download and read online PDF file Book Sap Nation 3 0 Manifest Destiny English Editi// [14.6 MB] with just a click.
# DAPA – DAPA is a statewide anti-poverty program that is available for eligible Filipino-Americans. It is a refundable tax credit for low and moderate income taxpayers. It is not a welfare program. DAPA is a tax credit and not a hand-out. It is a refundable tax credit for low and moderate income taxpayers and is not a welfare program.
#
# In 1986, President Ferdinand Marcos was overthrown by the People Power Revolution, and Corazon Aquino assumed the presidency. The first female president in the history of the Philippines, the widow of Benigno Aquino, who was assassinated by Marcos in 1983, Aquino was a symbol of the anti-Marcos movement.
#
# After 20 years as a democracy, the Philippines elected its first female president. Corazon Aquino became the first female president of the Philippines. She was elected in 1986. She is the widow of Benigno Aquino, who was assassinated by President Marcos in 1983. Although she had no political experience, she was a symbol of the anti-Marcos movement.
#
# During the term of President Benigno Aquino, the country had a relatively peaceful and prosperous period, known as the "Gold
# TEXTS:  26
# Irvin S. Naylor’s Black Jack Blues kept alive his American unbeaten streak with an authoritative 6 1/4-length victory in the $50,000 Carolina Cup (Gr.// 3) at Camden, S.C., March 24.
#
# The 5-year-old gelding, who had won the other two 2018-19 National Steeplechase Association races he ran, was the 1-5 favorite.
#
# Irvin S. Naylor’s Black Jack Blues stayed on the lead from the start under jockey Ross Geraghty.
#
# There was no chase as the other six rivals were not within 30 lengths, the required distance to be listed as being in a race, at the end of the 2 1/2-mile test.
#
# The winner completed the course in 5:18 2/5 on a soft turf.
#
# It was the third win in 10 career starts over fences for Black Jack Blues, who was bred in Kentucky by the late Jean-Luc Naylor. He is by English King out of the mare Bold Affair, who was bred by Jean-Luc and Irvin Naylor, the latter of whom campaigned the mare.
#
# Black Jack Blues was an $80,000 purchase by Irvin S. Naylor at the 2016 Keeneland January sale.
#
# The Naylor colors have been seen atop the winner’s circle at Camden for the past five years.
#
# TEXTS:  27
# One-Week Anniversary: Mr. & Mrs. BramsonThere are many special days in a person’s life in which the memories you make last a lifetime. This remained t//ure for Mr. & Mrs. Bramson as they celebrated their one-week anniversary last Friday.
#
# The Bramson’s wedding ceremony and reception was held on the grounds of the Belle Meade Plantation on May 14, 2016. The wedding ceremony took place at the front of the Mansion, and the reception was held in the Carriage House. The Bramson’s reception décor was minimal, yet elegant. The Carriage House had an open, airy feel as the floor-to-ceiling windows were open, and the doors were open to the side patio. The Carriage House’s exposed brick walls were a gorgeous backdrop to the reception. The Bramson’s wedding colors were champagne, white, and blush, and the flowers were beautiful shades of pink, coral, and blush.
#
# The Bramson’s wedding day was simply perfect. We loved that they chose to have their ceremony and reception at the same location. The ceremony was beautiful and elegant, and the reception was a true Southern celebration! A big thanks goes to The Bramson’s for letting us be a part of their one-week anniversary!
#
# A special thanks to the following vendors who helped make this day unforgettable:
#
# Photography: Studio 1212
#
# Floral: Vase and Vogue
#
# Cake:
# TEXTS:  28
# The solar power is now flowing though Kissimmee Utility Authority.
# As of Tuesday, customers of KUA along with five other Florida public power utilitie//is were energized with the first direct path-to-grid solar power from a solar farm in South Florida.
#
# KUA’s project consists of a 2.5-megawatt solar farm in Palm Beach County, and will generate more than 4.5 million kilowatt-hours of electricity per year. The solar power is currently being used by KUA customers.
#
# “This is a great day for Kissimmee Utility Authority and the state of Florida,” said Lynne Inch, general manager and CEO of KUA, in a statement. “This project is a significant step forward in our efforts to provide our customers with cost-effective and reliable energy.”
#
# The project is a joint effort between KUA and the Florida Municipal Power Pool, or FMPP, a coalition of 11 public power utilities in Florida. In addition to KUA, the other FMPP members involved in the project include the cities of Auburndale, Brooksville, Eustis, Lake City, Lake Wales, and Newberry.
#
# The FMPP Solar Farm is located in Palm Beach County on 25 acres of land, with a total of 12,000 solar panels. This new source of energy will produce enough clean, renewable energy to power more than 400 homes.
#
# “We are proud to be working with our FMPP partners and the city
# TEXTS:  29
# ABOUT THE ROLE. WHAT YOU'LL BE DOING • Building tight relationships with key business, finance and tech journalists in your market• From new products // to partnerships, we are constantly seeking to educate and inform key industry media• We are looking for a new member of the team to support the EMEA team in this mission • You will be responsible for pitching, drafting and executing media relations programmes in your market • Writing press releases, thought leadership by-lines, Q&As, case studies and other content that will form the basis of stories and articles• You will be tasked with creating and managing media lists for your market, as well as maintaining and expanding those lists• You will be building and managing relationships with key journalists, bloggers and influencers• You will be actively monitoring and tracking your teams’ results, and feeding valuable insights back into the team
#
# ABOUT YOU
#
# We’re looking for someone with the following experience and skills:
#
# • A strong communicator with a professional approach • Someone who can think on their feet and come up with creative solutions to challenges • A strong track record of PR campaigns, preferably in the tech sector • An understanding of the tech influencer landscape • Strong media contacts in your target market • Strong relationship building skills • A deep-seated passion for tech • An interest in the digital transformation of business • The ability to work with a team to come up with creative solutions to challenges • Experience in creating and managing media lists and databases • Experience in writing compelling copy, with an understanding of the different formats that journalists like to work with •
# TEXTS:  30
# Advancing Health Equity Through ACA Open Enrollment
# DENVER -- Coloradans of color are suffering significantly higher rates of COVID-19 infection and d//...
#
# We're here to help
#
# The Colorado Consumer Health Initiative (CCHI) is a non-partisan, non-profit membership organization dedicated to making high-quality, affordable health care a reality for all Coloradans, regardless of income or background.
#
# ## News
#
# - September 1, 2021
#
# ##### CCHI Supports the 2022 Legislative Priorities of the Colorado Immunization Coalition
#
# CCHI is proud to support the 2022 legislative priorities of the Colorado Immunization Coalition.
# - September 1, 2021
#
# ##### CCHI Supports the 2022 Legislative Priorities of the Colorado Oral Health Coalition
#
# CCHI is proud to support the 2022 legislative priorities of the Colorado Oral Health Coalition.
# - August 30, 2021
#
# ##### CCHI Supports the 2022 Legislative Priorities of the Colorado Children’s Immunization Coalition
#
# CCHI is proud to support the 2022 legislative priorities of the Colorado Children's Immunization Coalition.
# - August 17, 2021
#
# ##### CCHI Supports the 2022 Legislative Priorities of the Colorado
# TEXTS:  31
# ANTICORROSION PRIMERS We offer primers for coating systems with maximum service life expectancy. more INTERMEDIATE & BARRIER COATINGS Intermediate & b//ariers coatings for the best protection of your objects. more BASE COATS The right base coat for the protection of your object. more
#
# # CORRASIL^{®}
#
# ## Corrosion protection with CORRASIL^{®}
#
# CORRASIL^{®} is the brand name for the complete range of the corrosion protection technology of LINZER Chemieprodukte. The products of the CORRASIL^{®} range are used as anti-corrosion primers for the protection of steel and other construction and building materials against corrosion. With CORRASIL^{®} we offer our customers a complete range of products for the different stages of corrosion protection (cathodic protection, anodic protection, mixed potential protection) and for all types of corrosion (steel, steel-concrete, concrete).
#
# ### Corrosion
#
# Corrosion is the natural process of chemical weathering by which a metal or alloy surface is gradually destroyed by a chemical reaction with its environment. The most common corrosion mechanism is the electrochemical reaction, which requires an anode and a cathode. Both can be the same metal, such as in steel corrosion, or different metals, such as in the case of bimetallic corrosion.
#
# Corrosion can cause severe damage to
# TEXTS:  32
# During – “Where is everybody?” If there are alien civilizations out there, why haven’t we found any evidence of their SRPs?Continue reading “Maybe Sel//dom Reported Planets Are Just Part of an Intergalactic Game.”
#
# Forgetting is the only way to escape the past. – Alicia Whitney
#
# I was born a girl named Alicia. – Alicia Whitney
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
#
# Alicia Whitney: I was born a girl named Alicia.
# TEXTS:  33
# American Heritage Music Festival
# 1800 S Main St
# American Heritage Music Festival jamming and family camping. Daytime events and competitions are held //9:00 am to 5:00 pm. Music Jamming is 5:00 pm - 10:00 pm.
#
# ## Friday, August 30
#
# Morning:
# - Set Up Campsites
# - Daytime Events and Competitions, 9:00 am to 5:00 pm
# - Music Jamming, 5:00 pm - 10:00 pm
#
# ## Saturday, August 31
#
# - Set Up Campsites
# - Daytime Events and Competitions, 9:00 am to 5:00 pm
# - Music Jamming, 5:00 pm - 10:00 pm
#
# ## Sunday, September 1
#
# - Daytime Events and Competitions, 9:00 am to 5:00 pm
# - Music Jamming, 5:00 pm - 10:00 pm
#
# ## Lodging
#
# No lodging is planned. However, there are a number of hotels and campgrounds nearby.
#
# ## About the American Heritage Music Festival
#
# The American Heritage Music Festival was created to promote the preservation of traditional American music. The festival celebrates and showcases the best in the music of Bluegrass, Old-Time, Country, Cajun and Western Swing. The festival is located on the banks
# TEXTS:  34
# Welcome to visit us!
# Zhengzhou City
# 24hours
# ManufacturerofCrusher Machine- AutomaticStone Crushers,Stone CrusherPlant, JawCrusheroffered by AAR Bee En//trprise, Zhengzhou, China.
#
# - ### 30-Year-Old Man Crushed to Death in Stone Crushing
#
# Apr 16, 2016 A 30-year-old man was crushed to death in Karama, Mombasa County, after falling into an uncovered stone crusher. The man identified as Collins Orina was working at a stone crushing plant in Mtongwe area when the incident happened at around 5pm.
# - ### Crushing and Screening CME
#
# World class mining and crushing technologies. Crushing and Screening. CME offers a complete line of world-class crushing and screening solutions for every application. Our team of experts has a full solution to meet any need.
# - ### Crushing and Screening Plants
#
# The crushing, screening and washing plant is the heart of every quarry set-up, as this is the point where the main material transformation takes place. Our experts have designed the plant to meet the specific needs of your quarry site.
# - ### Crushing and Screening Equipment
#
# Crushing and Screening Equipment. Crushing and screening is a two-stage process in which rock is progressively reduced in size until it can be separated into the required aggregate categories and sizes. This process can be carried out using a single machine or a combination of machines.
# - ### Crushing and Screening Equipment Rentals and Sales
# TEXTS:  35
# RC race cars have been winning races and championships all over the west coast since the 1980’s. Our first championship season was the 1987 C.A.R.S. P//ure Stock Championship in Santa Cruz California.
#
# Our first race car was a 1976 Chevy Pure Stock, that we raced in the C.A.R.S. Pure Stock series from 1987 to 1989, winning 12 feature events and 1 championship, with the rest of the season in the top 3.
#
# We also have raced in the United States Auto Club (USAC) Stock Car series, winning feature events and championships from the early 1990’s to the present.
#
# We have also raced in the West Coast Short Track Championships (WCSTC) from the 1990’s to the present.
#
# In 2006, we switched to the Sprint Car division of the WCSTC, and won the championship in 2010 and 2018.
#
# In 2010 we added a 1993 Chevy Monte Carlo to our race team, and we run both cars in the 2019 WCSTC season.
#
# 2019 WCSTC Sprint Car
#
# 2019 WCSTC Late Model
#
# Here is a video of our 2019 WCSTC Sprint Car in action at the Modesto Raceway on April 14, 2019.
# TEXTS:  36
# About the game:
# Endless runner with Santa.
# Endless runner with Santa.
# Manage your small 10×10 field. Grow various crops and harvest it. Be smart when //2×2 fields fall down. Use the seeds of the field which fell down to grow new crop. If you can not manage to grow new crop, you will loose all the crops in the field.
# In the later levels, the number of crops in the field will decrease. So, you need to grow new crops very fast.
#
# ### How to play:
#
# Use mouse to rotate the field.
#
# ### Rating:
#
# This game is rated 9.5 out of 10 in the 2012 Christmas Games competition.
#
# ### Links:
#
# - Play the game online.
# - Source code of the game.
# - Source code of the game level editor.
# - Play the game offline.
# - WebGL version of the game (experimental).
# - HTML5 version of the game (experimental).
# - Android package of the game.
# - Play this game in your Android device.
# - Play this game in your iOS device.
# TEXTS:  37
# As MVPDs shape their approaches to bringing 4K Ultra HD services to market, the emergence of High Dynamic Range (HDR) technology signals that they wil//…
# DIPLOMATIC INCIDENT: It’s not the first time that the US has found itself in a diplomatic tussle with the Chinese, but this time it’s about a different…
# IT'S A WRAP: It was the year that saw the rise of OTT and the demise of cable, the year that saw 100-Mbps broadband go mainstream and the year that…
# THE BIGGEST OMNISPORT: With the World Cup in Brazil and the 2016 Summer Olympics in Rio de Janeiro, the city of São Paulo is quickly becoming the sport…
# THE WORLD IS YOUR OMNISPORT: The 2010 FIFA World Cup South Africa was the first global event to be broadcast in 3D and with the 2014 event in…
# IT'S A WRAP: 2014 was the year that saw the rise of OTT and the demise of cable, the year that saw 100-Mbps broadband go mainstream and the year that…
# THE BIGGEST OMNISPORT: With the World Cup in Brazil and the 2016 Summer Olympics in Rio de Janeiro, the city of São Paulo is becoming the sport…
# THE WORLD IS YOUR OMNISPORT: The 2010 FIFA World Cup South Africa was
# TEXTS:  38
# Add streaming config option for not emitting the key
# ----------------------------------------------------
# Key: MAPREDUCE-1785
# URL:
# Project: Hadoop Map//Reduce
# JIRA: MAPREDUCE-1785
# Affects Version: 0.20.0
# Fix Version/s: 0.20.0
# Components: mapred-client
# Labels:
# Reporter: josh
# Assignee: hadoop-dev
#
# We don't always want to emit the key. This is useful for example in
# MapReduce jobs that only emit (key,1) and when the reducers have to
# merge the (key,1)s that were emitted.
#
# There is a StreamingConfiguration.setMapOutputKeyType class, but that
# is only used to specify the type of key to be used by the map task
# and it is not used to specify the type of key to be used by the
# reduce task.
#
# I would like to be able to do something like:
#
# StreamingConfiguration.setMapOutputKeyType(Class<T> keyClass)
# TEXTS:  39
# Airport Transfers
# Our team is focused on providing to our costumers with the best possible service in terms of what we do.
# We provide safe and reliabl//be airport transfers to and from the main airports in the country.
# The staff in our company is carefully selected, and trained to provide a friendly and professional service.
# Airport Transfers
# Madeira is a beautiful island in the Atlantic Ocean, located about 300 kms from the mainland Portugal.
# The island of Madeira is the second largest Macaronesian archipelago, with a population of about 250,000 inhabitants.
# Madeira is known for its beautiful beaches and warm waters and wonderful mountain landscapes.
#
# ## About Us
#
# Atlantic Shuttle is a Madeiran company that provides airport transfers to and from the Funchal Airport.
#
# ## Our Services
#
# We provide airport transfers to and from the Funchal Airport, and also other services like:
#
# ## Contact Us:
#
# - Atlantic Shuttle
# - Rua João do Canto nº 56 - A
# - 9000-070 Funchal - Madeira
# - +351 963 474 428
# - info@atlanticshuttle.pt
#
# ### Get In Touch
#
# If you would like to contact us about anything, please fill in the form below:
# TEXTS:  40
# Guides To Choosing An Escape Room
# When it comes to the choosing of the escape room, a large number of people around the the world find it a very big p//alaver, but that should not be so. It would be a very good idea for you to choose the best escape room for you and your family, as it would be a great way to spend time with them. You should not feel like the escape room is an activity that is only for the children.
#
# You should make sure that you choose an escape room that is suitable for you and your family. You should make sure that you know the number of people that you are going to bring with you, as the group size differs from one escape room to the other. There are some escape rooms that would allow you to go in alone, while there are ones that would require you to bring along some team members. You should make sure that you find the appropriate escape room for you and your family.
#
# You should find out more about the kind of escape room you are looking into, as it would determine whether you should choose it or not. There are some escape rooms that are family oriented, while there are others that are designed for the kids. You should make sure that you choose an escape room that is designed for both adults and kids.
#
# You should find out more about the kind of escape room that you are looking into, as it would determine whether you should choose it or not. Some of the escape rooms are built in a way that they can accommodate a few people, as they require a team of people to solve the puzzle. You should make sure that
# TEXTS:  41
# Sushi Saturday!
# Mar 16, 2019
# Our friends fishing aboard the Sea Note are enjoying their big blue-fin today!
# Thanks for fishing with us and sharing the// action!
#
# Captain Mike
#
# #sushisaturday #bigbluefin #reelfishingcharters #deepseafishingcharters #bostonfishing #bostonfishingcharters #fishfight #bigfish #fishsaturdays
#
# This has been an awesome winter fishing season, and we are just getting started!
# March is here, and we are starting all of our charter trips with a bang!
#
# We are looking forward to another great season of big blue-fin tuna fishing, with our first trip out today!
#
# We are currently booking trips, so give us a call to get on the books!
#
# Captain Mike
#
# The fall season of 2015 was amazing, and we are getting ready for another great winter fishing season!
#
# We are booking trips now, and are currently taking reservations for trips in September through June.
#
# The winter fishing season is underway, and the fishing is awesome!
#
# We are taking trips to the canyons and the deep sea for tuna, and we are catching some nice blue-fin tuna fishing out of Boston!
#
# The weather is beautiful, and the fishing is great!
#
# We are booking trips now for the winter season.
#
# Give us a call to get on the books!
#
# Captain Mike
#
# We are booking fall and winter trips now!
#
# Give
# TEXTS:  42
# ...
#
# It is widely used to crush high hardness, large capacity, high humidity materials, widely used in ore dressing, building materials, chemical industry, coal, electric power and other industries with the characteristics of a variety of ore crushing, high product
#
# It is widely used in mining, smelting, building materials, roads, railways, water conservancy and chemical industry with the characteristics of high product yield and long service life.
#
# It is widely used in mining smelting, building materials, roads, railways, water conservancy and chemical industry with the characteristics of high product yield and long service life.
#
# It is widely used in mining, smelting, building materials, roads, railways, water conservancy and chemical industry with the characteristics of
# TEXTS:  188
# .
# Hand & Wrist Conditions
# Trigger Finger
# Inflammation in the tenosynovium leads to a condition called trigger finger, also known as stenosing tenosyno//itis. The tenosynovium is the sheath that surrounds the tendon. When this sheath becomes inflamed, the tendon slides less easily within the sheath. As a result, a finger may be stuck in a bent position and can only be straightened with force.
#
# Often, individuals with trigger finger experience a catching or locking sensation in their fingers, a nodule in the palm, or a popping in the fingers. The condition can affect any finger or the thumb. If more than one finger is involved, it usually affects the two middle fingers.
#
# ## Trigger finger symptoms
#
# - A catching, snapping, or locking sensation in the finger or thumb
# - A nodule in the palm
# - Pain in the palm
# - Pain in the palm
# - Pain in the palm
#
# ## Causes
#
# The primary cause of trigger finger is inflammation of the tenosynovium. The exact cause of this inflammation is unknown, but the condition is often associated with rheumatological diseases such as rheumatoid arthritis. It is also associated with diabetes, hypothyroidism (underactive thyroid), and Dupuytren's contracture. Trigger finger is most common in middle-aged women.
#
# ## Diagnosis
#
# Trigger finger is usually diagnosed based on an examination of the hand by a doctor. The doctor may
# TEXTS:  189
# Edwy Harrison - SHEQ Consultant
# Edwy joined the team in May 2017; focusing primarily on the construction industry. Due to his previous employment’s ra//unching from construction to manufacturing and food, he has a broad understanding of the Health and Safety Management systems, and his skills and knowledge are transferable to a wide range of sectors.
# Edwy is a qualified CITB Site Manager and a qualified IOSH Safety, Health and Environment for Construction Manager. He is an accredited trainer for CITB and NVQs, and a qualified NEBOSH General and Construction Certificate Trainer.
# He is the holder of two NEBOSH Diplomas, and is a Chartered Member of the Institution of Occupational Safety and Health (CMIOSH).
# Edwy has worked in the Health and Safety industry for over 15 years with over 30 years’ experience in the construction industry.
# He has been involved in all aspects of the Health and Safety Management Systems, and has a proven track record in the construction, food, manufacturing, and engineering industries.
# Edwy has vast experience in the development and implementation of Health and Safety Management Systems, and has been involved in the implementation of the BS OHAS 18001; and is a qualified auditor for the OHSAS 18001; and the ISO 14001.
# He has been involved in the development of HSE policies and procedures and the implementation of systems for the health and safety management, and the management of the environmental management systems. He has been
# TEXTS:  190
# Is it possible to create a USER defined waypoint when creating a flight plan in the App? I like using the android app a lot and it would be really nic// to be able to enter a way point as I’m building the plan.
#
# If I want to make a waypoint, I have to hit the back button, which takes me out of the flight plan and requires me to start over.
#
# I’m sure I’m missing something.
#
# Also, I would really like to see the flight plan on the map while I’m entering it.
#
# Also, is it possible to “add” or “subtract” from a flight plan? Ie, if I have a flight plan with a bunch of waypoints, I want to make a new flight plan with those same waypoints but one or two of them removed.
#
# Currently, I have to build the flight plan up from scratch which is a real pain.
#
# I want to build a flight plan with 8 waypoints/fuel stops from A to B, then, once in the air, I want to be able to add 4 more fuel stops along the way.
#
# The app, as it is currently, is not really useful to me. Thanks for listening.
# TEXTS:  191
# But at the same time, it can be extremely frustrating trying to get through with soccer drills for kids, mainly because kids have less understanding a// short while, the youngster would be so frustrated! However, these drills are meant to be an aid, not to be followed step-by-step and once you Pitch Engine and the pitch was free. The objective of these games is for players to master several of those moves by practicing them and knowing how to use them and perform them at the right time of the game. The objective of these games is for players to master several of those moves by practicing them and knowing how to use them and perform them at the right time of the game. When you ask a grown-up for 5 pounds, he will give it to you but not from freestyle soccer, the kids were outplaying us, Aquarone told the Goal magazine.
#
# In soccer scores, as in the baseball scores, the highest place of the components of the kit that are needed for a game of soccer. If an offensive guard blocks an opponent and "holds" him, they can either from the younger age groups would be Nike labels while older players would look for Mizuno and Asics. com for some of the most informative content on the web and by the scores, and then the third is how they perform in a given time frame. They will increase confidence, แทงบอลออนไลน์ แทงบอลออนไลน์ 168 especially of players who are not considered the best
# TEXTS:  192
# Has smartphone competition died in 2021?
# This article may contain personal views and opinion from the author.
# And I am not even going back to the Noki//agate of 2019, but I think it is safe to say that the competition in the mobile phone industry has died.
#
# The mobile phone industry and the competition between the biggest players in the industry have died. As the biggest players in the mobile phone industry are becoming less and less competitive and more and more competitive.
#
# The mobile phone industry is not dead. The mobile phone industry is not even dead-less.
#
# The mobile phone industry is dying. If you are a mobile phone company and you don’t have a marketing department, you are literally dead. If you aren’t doing marketing, you are not in the mobile phone industry. And if you don’t have a marketing department, you are not in the mobile phone industry.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying.
#
# The mobile phone industry is dying
# TEXTS:  193
# Wests Tigers have named a strong 22-man squad for their upcoming trial against the Parramatta Eels, to be played on Friday night at ANZAC Oval, Alice // Springs.
#
# With the game being named after the tragic passing of 19 year-old Parramatta player Mitchell Allgood, the Eels have been granted permission from the NRL to use 22 players in the game, with Wests Tigers to play 12.
#
# Wests Tigers will also be making their farewells to 2015 NYC players Tautau Moga, Matt McIlwrick and JJ Felise, who will all be named in the 22-man squad.
#
# Felise, who has been part of the Wests Tigers set-up since 2012, will be departing the Club to take up a contract with the NSW Waratahs for the 2016 Super Rugby season.
#
# Moga and McIlwrick, who have been part of the Club since 2009, have both been offered full-time NRL deals, and will continue to train with the NRL squad in the lead up to the season.
#
# Wests Tigers will also name a 14-man squad for the Under 20s clash against the Eels, with full details to be confirmed tomorrow.
#
# > Friday's game in Alice Springs will be played in honour of Parramatta player Mitchell Allgood, who passed away at the age of 19 on Monday.
#
#
# TEXTS:  194
# >>
# Mecca
# non-member comment
# River Boats
# Thanks for the entry. Always wondered what it would be like to baot up a canal in France and now I know vicari//ou...
#
# Mecca
#
# Mecca (مكة‎) is a city in the Hijaz of Western Saudi Arabia and the holiest city in Islam. Mecca is the site of the Kaaba, the structure to which Muslims around the world turn in prayer.
#
# Mecca is located about 70 km (40 mi) inland from Jeddah in the foothills of the Hejaz Mountains, and its residents are often referred to as Meccans. The population of the city is about 2 million.
#
# Mecca is at an elevation of 2,700 feet (823 m) above sea level, and has a cool desert climate (Köppen climate classification BWh) with very warm, dry summers and mild winters. Average annual rainfall is 11 inches (26.4 cm).
#
# Mecca is the birthplace of the Prophet Muhammad and is the destination of the annual Hajj for Muslims.
#
# The city has many historical sites, including pre-Islamic wells and cisterns and the tombs of Prophet Muhammad's companions.
#
# Mecca enjoys a privileged status under Saudi law. It is the only city in the country where alcohol is prohibited and all forms of gambling are illegal. Non-Muslims are not permitted to enter the city, with the exception of the foreign workers who
# TEXTS:  195
# League Cup • July 15, 2014
# Hotshot O’Donovan Guns Down Cheetahs
# Written By: Kenneth Ho
# Hougang United’s six-match unbeaten streak came to an end on Mo//…
# League Cup • June 22, 2014
# Cheetahs Pounce On Warriors
# Written By: Kenneth Ho
# Hougang United ended Warriors FC’s unbeaten streak with a 2-0 vic…
# League Cup • June 21, 2014
# Cheetahs Set To Unleash Jufri
# Written By: Kenneth Ho
# Hougang United’s Jufri Taha is set to make his return to S.League…
#
# League Cup • June 18, 2014
# Cheetahs’ Sweeper-Keeping Duo
# Written By: Kenneth Ho
# Hougang United goalkeeper Khairulhin Khalid and sweeper Nurhilmi Jasni …
#
# League Cup • June 14, 2014
# Cheetahs’ Flying Jumbo
# Written By: Kenneth Ho
# Hougang United’s flying fullback Fairoz Hasan has been a revelatio…
#
# League Cup • June 10, 2014
# Cheetahs Tame Lions In S.League
# Written By: Kenneth Ho
# Hougang United’s Jozef Kaplan scored his second S.League hat-trick a…
#
# TEXTS:  196
#  with her daughter Jaimi.Source:Supplied.”
# RELATED: Fifi Box missing from radio after death of Jaimi
# Lisa Curry with her daughter Jaimi after winning //2017’s Celebrity Apprentice.
# Source:News Corp Australia
#
# “Dear Jaimi,
#
# “Dear Jaimi,
#
# “You are loved, you are very, very loved.
#
# “We are so sad and so devastated.
#
# “There is not a single person in our family who doesn’t love you, so so much.
#
# “I just want to say, how much we love you and how much you are going to be missed.
#
# “We are all feeling this.
#
# “This is not just me, it’s all of us.
#
# “This is the hardest thing I’ve ever had to do.”
#
# Jaimi was a former winner of Celebrity Apprentice who had been in a long battle with a reported eating disorder.
#
# She had been in and out of rehab in recent years, and was last seen publicly in October 2019.
#
# She reportedly had a stroke in 2017, and had a long road to recovery, with her mother and father, former Olympic swimmer and now racing analyst Todd Curry, by her side.
#
# In 2019, Lisa opened up about Jaimi’s health issues.
#
# “Jaimi has had a really tough time. She had a stroke a few years ago and she’
# TEXTS:  197
# THE FIRST PAINTING OF M.A. RAHMAN CHUGHTAI
# NUR JAHAN MOURNING AT JAHANGEERS TOMB
# A teenager’s fantasy and birth of Chughtai Art
# Art activity was in fu//elled by the teenage years of M.A. Rahman Chughtai. He was a teenager in the late 1920s and 1930s, and he would look at the paintings in the galleries of the Aligarh Museum. He would copy them in his room, and his favorite was the portrait of Nur Jahan mourning at the tomb of her husband the Emperor Jahangir. The portrait, painted by Mansur is a classic and it was a delight for the young artist to copy it. He made many such copies, and he called them ‘Miniatures’. Nowadays, they are known as ‘Studies’. There is also a study by him of the portrait of the Emperor Jahangir, painted by Abul Hasan. He made these during the 1930s, and these are now in the Chughtai museum.
# In 1936 he made a painting of a woman mourning at a tomb, and this is the first painting of M.A. Rahman Chughtai. This painting is the first work of art by him, and a study of a work of art by him, and a study of a work of art by him. This painting is now in the Chughtai museum. The painting shows a woman mourning at a tomb, and there is an inscription in Urdu in the lower right corner. ‘Jah
# TEXTS:  198
# The prospect of Leeds pitching up at Crawley and Marcelo Bielsa, one of the game’s most revered coaches, squatting beside his cushioned and commercial//ised dugout is a curious one.
# However, it’s one that will be repeated many times in the coming years as Leeds, with Bielsa and his army of analysts, scouts and data-crunchers set about the task of reclaiming their status in the Premier League, and the game goes through a period of change.
#
# For the first time, the Premier League’s promotion and relegation system will see a club promoted and relegated from the Championship, a club promoted and relegated from League One, a club promoted and relegated from League Two and a club promoted and relegated from the National League.
#
# It’s a new era of promotion and relegation. A new era for the club that is not a ‘big one’, but one that has just enough funding and the right idea to make the jump.
#
# Bielsa and his coaching team are already working on their plans to take Leeds to the next level. With the transfer window now open, they can begin to realise some of their ambitions in the transfer market.
#
# In this series, we’ll be looking at the current crop of Leeds United players, assessing their form and their suitability to the vision Bielsa has for Leeds.
#
# We’ll look at the squad as a whole, how Leeds are set up to take on the new Championship, and the areas in which
# TEXTS:  199
# The train to Nagoya was crowded, so I and another girl named Emily were the only two in our group to get seats at first. Even though we'd all gotten u//don noodles for dinner, we were all hungry, so we went in search of food. We stopped at a place called "Kanayama" (I think), which had a lot of food, but the prices were a bit steep, so we went to a place called "Kanayama Yatai Dining" (I think), which was cheap and had good food. After we ate, we all went back to the hotel.
#
# The next day, we got up at 6, and got ready to go to the shrines. We took a train to a station called "Atsuta", and got a cab to the shrine. There were a lot of people there, and a lot of the people were wearing yukata. We went to the shrine, and got rice balls, and there were lots of shrines and buildings, and there was a big torii gate. There were torii gates everywhere, and a lot of people were drinking tea. After a while, we got some tea, and then went back to Atsuta. At Atsuta, we went back to our hotel, and then had lunch at the hotel, and then went back to Atsuta Station, and then back to Nagoya. We had a lot of time, so we went back to the hotel, and then went to the Nagoya Castle Museum, which had a lot of stuff. We went back to Nagoya, and

# %%
# has date

import re

def contains_date_time(texts):
    # Regex pattern to match dates, times, and durations
    pattern = r"\b(?:\d{4}|\d{1,2}:\d{2}|\b(?:Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday)|\b\d{1,2}(?:st|nd|rd|th)?\s(?:January|February|March|April|May|June|July|August|September|October|November|December)|\d+\syears)\b"

    # List to store the results
    result = []

    for text in texts:
        # Search for the pattern in the text
        if re.search(pattern, text):
            result.append(True)
        else:
            result.append(False)


    return result


has_date = contains_date_time([i[1] for i in loaded_texts])

# %%
# Models
class ImprovedTwoLayerNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ImprovedTwoLayerNN, self).__init__()
        # Increase depth and capacity
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.relu1 = nn.LeakyReLU()
        self.batch_norm1 = nn.BatchNorm1d(hidden_size)
        self.dropout1 = nn.Dropout(0.5)  # Adjust dropout rate as needed
        
        # Additional layer
        self.layer2 = nn.Linear(hidden_size, hidden_size * 2)
        self.relu2 = nn.LeakyReLU()
        self.batch_norm2 = nn.BatchNorm1d(hidden_size * 2)
        self.dropout2 = nn.Dropout(0.5)  # Adjust dropout rate as needed
        
        # Output layer
        self.layer3 = nn.Linear(hidden_size * 2, output_size)
    
    def forward(self, x):
        x = self.layer1(x)
        x = self.relu1(x)
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        
        x = self.layer2(x)
        x = self.relu2(x)
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        
        x = self.layer3(x)
        return x
    
class TwoLayerNN(nn.Module):
    def __init__(self, input_size, hidden_size,  output_size):
        super(TwoLayerNN, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        x = self.layer1(x)
        x = self.relu(x)
        x = self.layer2(x)
        return x


# Takes in batch, seq_len, features
class CustomTransformerModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(CustomTransformerModel, self).__init__()
        self.embedding = nn.Linear(input_size, 4096) # Example embedding size
        self.transformer_block = nn.TransformerEncoderLayer(d_model=4096, nhead=8)
        self.output_linear = nn.Linear(4096, output_size)
        self.sigmoid = nn.Sigmoid()
        self.output_size = output_size

    def forward(self, x):
        x = self.embedding(x)
        x = x.permute(1, 0, 2) # Transformer expects [seq_len, batch, features]
        x = self.transformer_block(x)
        x = x.permute(1, 0, 2) # Revert permutation
        x = self.output_linear(x)
        x = x[:, -1, -1]
        x = self.sigmoid(x)
        return x

# %%
# train


def train(data_in, data_out, model, criterion, num_epochs, save=False, learning_rate=0.001):
    
    
    # Create a complete dataset
    full_dataset = TensorDataset(data_in.to("cuda"), data_out.to("cuda"))

    # Define the sizes for your training and validation sets
    total_size = len(full_dataset)
    train_size = int(0.8 * total_size)
    val_size = total_size - train_size

    # Split the dataset
    train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

    # Create DataLoaders for both training and validation sets
    train_dataloader = DataLoader(train_dataset, batch_size=400, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=500)  # No need to shuffle the validation data


    model.to("cuda")
     
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)



    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, targets in train_dataloader:
            inputs, targets = inputs.to("cuda"), targets.to("cuda")
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            
         
            running_loss += loss.item() * inputs.size(0)
    
        epoch_loss = running_loss / len(train_dataloader.dataset)
        # Validation phase
        model.eval()  # Set the model to evaluation mode
        running_loss = 0.0
        with torch.no_grad():  # No gradients need to be calculated
            for inputs, targets in val_dataloader:
                inputs, targets = inputs.to("cuda").float(), targets.to("cuda").float()
                outputs = model(inputs)
                
                loss = criterion(outputs, targets)
                running_loss += loss.item() * inputs.size(0)
        val_loss = running_loss / len(val_dataloader.dataset)

        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.8f}, Validation Loss: {val_loss:.8f}')
        
    if(save):
        # Ensure the model is in evaluation mode
        model.eval()

        predictions = []
        with torch.no_grad():  # No gradients needed for inference
            for inputs, _ in full_dataset:  # Assuming your dataset returns inputs and targets
                inputs = inputs.to('cuda').float().unsqueeze(0)
                
                # Get the model output
                outputs = model(inputs)
                

                predictions.append(outputs.cpu())

        # Concatenate all batches of predictions
        all_predictions = torch.stack(predictions, dim=0)

        # Save the tensor to a file
        torch.save(all_predictions, 'model_predictions.pth')

# %%
# activations 
# list 
#   atten out
#   ff out
#   output 

data_out = (torch.tensor(has_date)* 1).float()

# use last layer on four last tokens
data_in = torch.stack([i[1][-1, :, :] for i in activations]).float()    


criterion = nn.CrossEntropyLoss() 


model = CustomTransformerModel(input_size=4096, output_size=2).to("cuda")

# %%
data_in
# Out:
# tensor([[[  0.7773,   6.2734,   0.5830,  ...,   1.3037,  -1.9346,   1.3467],
#          [ -2.0098,  -0.2891,  -3.8477,  ...,  -2.1738,   0.0838,   4.3867],
#          [  1.1191,   1.2549,   3.3477,  ...,  -0.8857,  -0.8481,   0.9170],
#          [  2.6602,  -1.6709,   3.2285,  ...,   0.9634,   0.8730,   2.1328]],
#
#         [[  6.4375,   1.4395,   2.4395,  ...,  -3.9746,   1.0781,  -8.5625],
#          [ -0.1475,  -1.6270,  -3.5098,  ...,  -9.5000,   2.4473,  -2.8086],
#          [ -3.4727,  -1.8193,   0.9170,  ...,  -4.6250,  -2.0703,  -2.3867],
#          [  0.0161,  -1.9463,   0.3103,  ...,  -3.3926,  -0.2717,  -5.7773]],
#
#         [[  0.4756,   4.1289,   3.8398,  ...,   2.7793,   6.8516,  -1.1924],
#          [ -5.7070,   4.3398,   1.9834,  ...,  -1.5527,   7.6680,   5.0039],
#          [ -4.6562,   6.6992,   0.1177,  ...,   0.0263,  -3.3672,  -3.0430],
#          [ -0.6230,   8.7500,   0.9990,  ...,  -4.9336,   2.6875,  -0.1174]],
#
#         ...,
#
#         [[ -2.5039,  -3.5957,   2.9297,  ...,  -3.5215,  -4.4688,  -0.1010],
#          [  3.5312,   4.3867,   2.0879,  ...,  -5.8242,  -1.4756,  -2.4922],
#          [  5.3516,   9.0547,   0.3892,  ...,   1.1885,   5.0312,  -2.5625],
#          [  2.4102,  -1.2090,  -0.1343,  ...,  -6.8008,   5.0938,  -5.1484]],
#
#         [[  1.2119,   9.5312,  -2.1895,  ...,   1.5400,  -2.6934,  -8.5078],
#          [  2.5195,   1.3369,  -1.4473,  ...,   0.3640,  -1.2842,   0.8364],
#          [ -3.8184,   2.1855,  -1.6289,  ...,   6.9297,  -4.6797,  -7.4922],
#          [  2.8555,   5.3750,  -0.3010,  ...,   0.7568,  -0.7070,  -2.1582]],
#
#         [[  4.4688,   1.4287,  -3.3086,  ...,   2.1836,  -0.2052,  -3.3945],
#          [  6.0703,  -4.0938,  -2.7695,  ...,  -3.8223,  -2.4863,   2.0430],
#          [  4.4766,  -3.5938,  -2.9492,  ...,  -1.6240,  -0.4932,   4.2773],
#          [  7.5508,   5.5586,   1.4111,  ...,   1.3281, -10.2578,   4.2422]]],
#        device='cuda:0')

# %%
train(data_in, data_out, model, criterion, num_epochs=10, save=True, learning_rate=0.0001)
# Out:
# Epoch [1/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [2/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [3/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [4/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [5/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [6/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [7/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [8/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [9/10], Training Loss: 0.00000000, Validation Loss: 0.00000000
# Epoch [10/10], Training Loss: 0.00000000, Validation Loss: 0.00000000

# %%
model(data_in[0:5]).unsqueeze(1).to("cuda").device
# Out:
# device(type='cuda', index=0)

# %%
data_out[0:5].to("cuda").type(torch.LongTensor).to("cuda")
# Out:
# tensor([1, 1, 0, 0, 0], device='cuda:0')

# %%
criterion(model(data_in[0:5]).unsqueeze(1).to("cuda") , data_out[0:5].to("cuda").type(torch.LongTensor)  )

# %%
model(data_in[0:5]).unsqueeze(1).to("cuda")
# Out:
# tensor([[0.5513],
#         [0.3506],
#         [0.4965],
#         [0.2890],
#         [0.5728]], device='cuda:0', grad_fn=<UnsqueezeBackward0>)

# %%
# Takes in batch, seq_len, features
class CustomTransformerModel2(nn.Module):
    def __init__(self, input_size, output_size):
        super(CustomTransformerModel2, self).__init__()
        self.embedding = nn.Linear(input_size, 4096) # Example embedding size
        self.transformer_block = nn.TransformerEncoderLayer(d_model=4096, nhead=8)
        self.output_linear = nn.Linear(4096, output_size)
        self.sigmoid = nn.Sigmoid()
        self.output_size = output_size

    def forward(self, x):
        x = self.embedding(x)
        print(x.shape)
        x = x.permute(1, 0, 2) # Transformer expects [seq_len, batch, features]
        print(x.shape)
        x = self.transformer_block(x)
        print(x.shape)
        x = x.permute(1, 0, 2) # Revert permutation
        print(x.shape)

        x = self.output_linear(x)
        print(x.shape)
        x = self.sigmoid(x)
        return x[:, -1, -1]

# %%
mx = CustomTransformerModel2(10, 2)

a = mx.forward(torch.rand(3, 2, 10, 10))
# Out:
# torch.Size([3, 2, 10, 4096])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[57], line 3
#       1 mx = CustomTransformerModel2(10, 2)
# ----> 3 a = mx.forward(torch.rand(3, 2, 10, 10))
#
# Cell In[54], line 14, in CustomTransformerModel2.forward(self, x)
#      12 x = self.embedding(x)
#      13 print(x.shape)
# ---> 14 x = x.permute(1, 0, 2) # Transformer expects [seq_len, batch, features]
#      15 print(x.shape)
#      16 x = self.transformer_block(x)
#
# RuntimeError: permute(sparse_coo): number of dimensions in the tensor input does not match the length of the desired ordering of dimensions i.e. input.dim() = 4 is not equal to len(dims) = 3

# %%
a
# Out:
# tensor([0.6200, 0.6040], grad_fn=<SelectBackward0>)

# %%
loss = nn.CrossEntropyLoss()
input = torch.randn(3, 5, requires_grad=True)
target = torch.empty(3, dtype=torch.long).random_(5)
output = loss(input, target)

# %%
target.dtype
# Out:
# torch.int64
